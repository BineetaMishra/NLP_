# %%
# Creating a simple function that cn read a file
def read_file(filepath):
    with open(filepath) as f:
        str_text= f.read()
    return str_text

# %%
#read_file('moby_dick_four_chapters.txt')

# %% [markdown]
# Text cleaning

# %%
import spacy

# %%
# since only tokenization is required rest all features can be disabled
nlp= spacy.load('en',disable=["parser","tagger","ner"])

# %%
nlp.max_length= 1198623

# %%
# a function to seperate puncutation
def seperate_punc(doc_text):
    return[token.text.lower() for token in nlp(doc_text) if token.text not in '\n\n\n\n!"-#$%$()--.*,-/\n']

# %%
d = read_file('moby_dick_four_chapters.txt')

# %%
tokens = seperate_punc(d)

# %%
len(tokens)
# Out:
# 11822

# %% [markdown]
# Pass in First 25 words and have Network Predict the 26th Word.

# %%
train_len = 25 + 1

text_sequences=[]

for i in range(train_len,len(tokens)):
    seq=tokens[i-train_len:i]
    
    text_sequences.append(seq)

# %%
type(text_sequences)
# Out:
# list

# %%
text_sequences[0]
# Out:
# ['call',
#  'me',
#  'ishmael',
#  ' ',
#  'some',
#  'years',
#  'ago',
#  'never',
#  'mind',
#  'how',
#  'long',
#  'precisely',
#  'having',
#  'little',
#  'or',
#  'no',
#  'money',
#  'in',
#  'my',
#  'purse',
#  'and',
#  'nothing',
#  'particular',
#  'to',
#  'interest',
#  'me']

# %%
text_sequences[1]
# Out:
# ['me',
#  'ishmael',
#  ' ',
#  'some',
#  'years',
#  'ago',
#  'never',
#  'mind',
#  'how',
#  'long',
#  'precisely',
#  'having',
#  'little',
#  'or',
#  'no',
#  'money',
#  'in',
#  'my',
#  'purse',
#  'and',
#  'nothing',
#  'particular',
#  'to',
#  'interest',
#  'me',
#  'on']

# %%
' '.join(text_sequences[0])
# Out:
# 'call me ishmael   some years ago never mind how long precisely having little or no money in my purse and nothing particular to interest me'

# %%
' '.join(text_sequences[1])
# Out:
# 'me ishmael   some years ago never mind how long precisely having little or no money in my purse and nothing particular to interest me on'

# %% [markdown]
# # Use Keras Tokenization to Format into a Numerical System

# %%
from keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_sequences)

# %%
sequences = tokenizer.texts_to_sequences(text_sequences)

# %%
sequences[0]
# Out:
# [960,
#  16,
#  266,
#  4,
#  54,
#  264,
#  411,
#  90,
#  222,
#  132,
#  114,
#  958,
#  263,
#  53,
#  46,
#  41,
#  318,
#  8,
#  25,
#  550,
#  3,
#  153,
#  262,
#  7,
#  2715,
#  16]

# %% [markdown]
# EACH OF THESE NUMBER IS AN ID TO A PARTICULAR WORD.

# %%
#sequences[1]

# %%
tokenizer.index_word
# Out:
# {1: 'the',
#  2: 'a',
#  3: 'and',
#  4: ' ',
#  5: 'of',
#  6: 'i',
#  7: 'to',
#  8: 'in',
#  9: 'it',
#  10: 'that',
#  11: 'he',
#  12: 'his',
#  13: 'was',
#  14: ';',
#  15: 'but',
#  16: 'me',
#  17: 'with',
#  18: 'as',
#  19: 'at',
#  20: 'this',
#  21: 'you',
#  22: 'is',
#  23: 'all',
#  24: 'for',
#  25: 'my',
#  26: 'on',
#  27: 'be',
#  28: "'s",
#  29: 'not',
#  30: 'from',
#  31: 'there',
#  32: 'one',
#  33: 'up',
#  34: '?',
#  35: 'what',
#  36: 'him',
#  37: 'so',
#  38: 'bed',
#  39: 'now',
#  40: 'about',
#  41: 'no',
#  42: 'into',
#  43: 'by',
#  44: 'were',
#  45: 'out',
#  46: 'or',
#  47: 'harpooneer',
#  48: 'had',
#  49: 'then',
#  50: 'have',
#  51: 'an',
#  52: 'upon',
#  53: 'little',
#  54: 'some',
#  55: 'old',
#  56: 'like',
#  57: 'if',
#  58: 'they',
#  59: 'would',
#  60: 'do',
#  61: 'over',
#  62: 'landlord',
#  63: 'thought',
#  64: 'room',
#  65: 'when',
#  66: 'could',
#  67: "n't",
#  68: 'night',
#  69: 'here',
#  70: 'head',
# ...

# %%
for i in sequences[0]:
    print(f"{i}:{tokenizer.index_word[i]}")
# Out:
# 960:call
# 16:me
# 266:ishmael
# 4:
# 54:some
# 264:years
# 411:ago
# 90:never
# 222:mind
# 132:how
# 114:long
# 958:precisely
# 263:having
# 53:little
# 46:or
# 41:no
# 318:money
# 8:in
# 25:my
# 550:purse
# 3:and
# 153:nothing
# 262:particular
# 7:to
# 2715:interest
# 16:me

# %%
tokenizer.word_counts # Show how many times the word appears.
# Out:
# OrderedDict([('call', 27),
#              ('me', 2472),
#              ('ishmael', 133),
#              (' ', 8480),
#              ('some', 759),
#              ('years', 136),
#              ('ago', 85),
#              ('never', 450),
#              ('mind', 165),
#              ('how', 322),
#              ('long', 375),
#              ('precisely', 38),
#              ('having', 143),
#              ('little', 768),
#              ('or', 951),
#              ('no', 1004),
#              ('money', 121),
#              ('in', 5648),
#              ('my', 1787),
#              ('purse', 72),
#              ('and', 9647),
#              ('nothing', 282),
#              ('particular', 153),
#              ('to', 6498),
#              ('interest', 25),
#              ('on', 1716),
#              ('shore', 26),
#              ('i', 7150),
#              ('thought', 676),
#              ('would', 702),
#              ('sail', 104),
#              ('about', 1014),
# ...

# %%
vocabulary_size= len(tokenizer.word_counts)

# %%
vocabulary_size # 2721 unique words across the first four chapters
# Out:
# 2721

# %%
type(sequences)
# Out:
# list

# %% [markdown]
# Convert the sequences to numpy matrix

# %%
import numpy as np

# %%
sequences = np.array(sequences)

# %%
sequences
# Out:
# array([[ 960,   16,  266, ...,    7, 2715,   16],
#        [  16,  266,    4, ..., 2715,   16,   26],
#        [ 266,    4,   54, ...,   16,   26,  961],
#        ...,
#        [ 956,   13,  169, ...,  265,   56,    2],
#        [  13,  169, 2716, ...,   56,    2, 2721],
#        [ 169, 2716,    3, ...,    2, 2721,   28]])

# %% [markdown]
# # Split the data into features and labels
# --->X features (first n words of sequence)
#
#
# --->Y features (next words after sequence)

# %%
from keras.utils import to_categorical

# %%
X = sequences[:,:-1] # take everything except the last column

# %%
Y = sequences[:,-1] # take the last column

# %%
print(X)
print()
print("Now Y (Labels)")
print()
print(Y)
# Out:
# [[ 960   16  266 ...  262    7 2715]
#  [  16  266    4 ...    7 2715   16]
#  [ 266    4   54 ... 2715   16   26]
#  ...
#  [ 956   13  169 ...   12  265   56]
#  [  13  169 2716 ...  265   56    2]
#  [ 169 2716    3 ...   56    2 2721]]
#
# Now Y (Labels)
#
# [  16   26  961 ...    2 2721   28]

# %%
Y = to_categorical(Y, num_classes=vocabulary_size+1)

# %%
seq_len = X.shape[1]

# %%
X.shape
# Out:
# (11796, 25)

# %%
 X.shape[1]
# Out:
# 25

# %%
from keras.models import Sequential
from keras.layers import Dense,LSTM,Embedding

# %%
def create_model(vocabulary_size,seq_len):
    model= Sequential()
    model.add(Embedding(vocabulary_size, seq_len,input_length=seq_len))
    model.add(LSTM(50,return_sequences=True))
    model.add(LSTM(50))
    model.add(Dense(50,activation='relu'))
    
    model.add(Dense(vocabulary_size,activation="softmax"))
    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    model.summary()
    
    return model

# %%
model= create_model(vocabulary_size+1,seq_len)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding (Embedding)        (None, 25, 25)            68050
# _________________________________________________________________
# lstm (LSTM)                  (None, 25, 50)            15200
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 50)                2550
# _________________________________________________________________
# dense_1 (Dense)              (None, 2722)              138822
# ...
# Total params: 244,822
# Trainable params: 244,822
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Generate a new text

# %%
from pickle import dump,load

model.fit(X,Y,batch_size=128,epochs=2,verbose=1)
# Out:
# Epoch 1/2
# 93/93 [==============================] - 19s 91ms/step - loss: 7.4409 - accuracy: 0.0276
# Epoch 2/2
# 93/93 [==============================] - 9s 93ms/step - loss: 6.3355 - accuracy: 0.0479 1s - loss: 6.3378 - ac - ETA: 0s - loss: 6.3364 -

# %%
model.save('my_mobydick_model.h5')

# %%
dump(tokenizer,open('my_simpletokenizer','wb'))

# %% [markdown]
# # Create a function that generates new text based on model, tokenizer, seq_len, seed test, no. of words to be genarted by model

# %%
from keras.preprocessing.sequence import pad_sequences

# %%
def generate_text(model,tokenizer,seq_len,seed_text,num_gen_words):
    
    output_text=[]
    
    input_text = seed_text
    
    for i in range(num_gen_words):
        
        encoded_text= tokenizer.texts_to_sequences([input_text])[0]
        
        pad_encoded = pad_sequences([encoded_text], maxlen=seq_len,truncating='pre')
        
        pred_word_ind = model.predict_classes(pad_encoded,verbose=0)[0]
        
        pred_word= tokenizer.index_word[pred_word_ind]
        
        input_text+= ' '+pred_word
        
        
        output_text.append(pred_word)
        
        return ' '.join(output_text)

# %%
text_sequences[0]
# Out:
# ['call',
#  'me',
#  'ishmael',
#  ' ',
#  'some',
#  'years',
#  'ago',
#  'never',
#  'mind',
#  'how',
#  'long',
#  'precisely',
#  'having',
#  'little',
#  'or',
#  'no',
#  'money',
#  'in',
#  'my',
#  'purse',
#  'and',
#  'nothing',
#  'particular',
#  'to',
#  'interest',
#  'me']

# %%
import random
random.seed(101)
random_pick= random.randint(0,len(text_sequences))

# %%
random_seed_text= text_sequences[random_pick]

# %%
random_seed_text
# Out:
# ['one',
#  ' ',
#  'taking',
#  'up',
#  'his',
#  'tomahawk',
#  'from',
#  'the',
#  'table',
#  'he',
#  'examined',
#  'the',
#  'head',
#  'of',
#  'it',
#  'for',
#  'an',
#  'instant',
#  'and',
#  'then',
#  'holding',
#  'it',
#  'to',
#  'the',
#  'light',
#  'with']

# %%
seed_text = ' '.join(random_seed_text)

# %%
seed_text
# Out:
# 'one   taking up his tomahawk from the table he examined the head of it for an instant and then holding it to the light with'

# %%
generate_text(model,tokenizer,seq_len,seed_text,num_gen_words=25)
# Out:
# 'the'

# %%
from keras.models import load_model

# %%
model = load_model('epochBIG.h5')

# %%
tokenizer = load(open('epochBIG', 'rb'))

# %%
generate_text(model,tokenizer,seq_len,seed_text,num_gen_words=25)
# Out:
# 'his'
